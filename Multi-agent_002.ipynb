# %%
# !conda create -n crewai python=3.11
# !conda activate crewai -
# %pip install -U 'crewai[tools]' mdpdf
# Out:
# Requirement already satisfied: mdpdf in /opt/conda/envs/r/lib/python3.12/site-packages (0.0.18)
# Requirement already satisfied: crewai[tools] in /opt/conda/envs/r/lib/python3.12/site-packages (0.22.5)
# Collecting crewai[tools]
#   Using cached crewai-0.28.8-py3-none-any.whl.metadata (13 kB)
# Collecting appdirs<2.0.0,>=1.4.4 (from crewai[tools])
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (8.1.7)
# Collecting crewai-tools<0.2.0,>=0.1.7 (from crewai[tools])
#   Using cached crewai_tools-0.1.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.98 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (0.1.98)
# Requirement already satisfied: instructor<0.6.0,>=0.5.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (0.5.2)
# Requirement already satisfied: langchain<0.2.0,>=0.1.10 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (0.1.13)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (1.14.3)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (1.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (1.23.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (1.23.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (2.5.0)
# Requirement already satisfied: python-dotenv==1.0.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (1.0.0)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai[tools]) (2023.12.25)
# Requirement already satisfied: pymupdf>=1.21 in /opt/conda/envs/r/lib/python3.12/site-packages (from mdpdf) (1.24.0)
# Requirement already satisfied: commonmark>=0.9 in /opt/conda/envs/r/lib/python3.12/site-packages (from mdpdf) (0.9.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.22 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.4.24)
# Requirement already satisfied: lancedb<0.6.0,>=0.5.4 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.5.7)
# Collecting pydantic<3.0.0,>=2.4.2 (from crewai[tools])
#   Using cached pydantic-2.7.0-py3-none-any.whl.metadata (103 kB)
# Requirement already satisfied: pyright<2.0.0,>=1.1.350 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.1.355)
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (8.1.1)
# Requirement already satisfied: pytube<16.0.0,>=15.0.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (15.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.31.0)
# Requirement already satisfied: selenium<5.0.0,>=4.18.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.18.1)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.13.1)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.47.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.1.43)
# Requirement already satisfied: langchain-openai<0.0.6,>=0.0.5 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.0.5)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (3.5.0)
# Requirement already satisfied: pypdf<4.0.0,>=3.11.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (3.17.4)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.3.4)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (13.7.1)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.7.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.0.27)
# Requirement already satisfied: tiktoken<0.6.0,>=0.5.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.5.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai[tools]) (3.9.3)
# Requirement already satisfied: docstring-parser<0.16,>=0.15 in /opt/conda/envs/r/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai[tools]) (0.15)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /opt/conda/envs/r/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai[tools]) (8.2.3)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from instructor<0.6.0,>=0.5.2->crewai[tools]) (0.9.4)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/envs/r/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (6.0.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/conda/envs/r/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/envs/r/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.29 in /opt/conda/envs/r/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.0.29)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.33 in /opt/conda/envs/r/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.1.33)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/conda/envs/r/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (0.1.38)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/envs/r/lib/python3.12/site-packages (from langchain<0.2.0,>=0.1.10->crewai[tools]) (1.26.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (0.26.0)
# Requirement already satisfied: sniffio in /opt/conda/envs/r/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/envs/r/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/conda/envs/r/lib/python3.12/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (4.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/envs/r/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (1.2.14)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (6.11.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/jupyter/.local/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (1.61.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.23.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (1.23.0)
# Requirement already satisfied: opentelemetry-proto==1.23.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (1.23.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /home/jupyter/.local/lib/python3.12/site-packages (from opentelemetry-proto==1.23.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (4.25.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.44b0 in /opt/conda/envs/r/lib/python3.12/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai[tools]) (0.44b0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.4.2->crewai[tools]) (0.6.0)
# Collecting pydantic-core==2.18.1 (from pydantic<3.0.0,>=2.4.2->crewai[tools])
#   Downloading pydantic_core-2.18.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: PyMuPDFb==1.24.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from pymupdf>=1.21->mdpdf) (1.24.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/r/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor<0.6.0,>=0.5.2->crewai[tools]) (1.9.4)
# Requirement already satisfied: Mako in /opt/conda/envs/r/lib/python3.12/site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.3.2)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/r/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.13.3->crewai[tools]) (3.6)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.5)
# Requirement already satisfied: build>=1.0.3 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.1.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.110.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/conda/envs/r/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.29.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.17.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.44b0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.15.2)
# Requirement already satisfied: pypika>=0.48.9 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (7.7.0)
# Requirement already satisfied: importlib-resources in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /home/jupyter/.local/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.59.3)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.1.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/conda/envs/r/lib/python3.12/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.9.15)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai[tools]) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai[tools]) (0.9.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/envs/r/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (1.16.0)
# Requirement already satisfied: PyGithub<2.0.0,>=1.59.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.59.1)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.38 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.1.42)
# Requirement already satisfied: youtube-transcript-api<0.7.0,>=0.6.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.6.2)
# Requirement already satisfied: yt_dlp<2024.0.0,>=2023.11.14 in /opt/conda/envs/r/lib/python3.12/site-packages (from embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2023.12.30)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /home/jupyter/.local/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.14.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.23.4)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.22.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/envs/r/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.14.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (3.13.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.10.4)
# Requirement already satisfied: shapely<3.0.0dev in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.0.2)
# Requirement already satisfied: cachetools in /home/jupyter/.local/lib/python3.12/site-packages (from gptcache<0.2.0,>=0.1.43->embedchain<0.2.0,>=0.1.98->crewai[tools]) (5.3.2)
# Requirement already satisfied: certifi in /opt/conda/envs/r/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai[tools]) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/r/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai[tools]) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/r/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai[tools]) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/r/lib/python3.12/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (3.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/envs/r/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain<0.2.0,>=0.1.10->crewai[tools]) (2.4)
# Requirement already satisfied: deprecation in /opt/conda/envs/r/lib/python3.12/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.1.0)
# Requirement already satisfied: pylance==0.9.18 in /opt/conda/envs/r/lib/python3.12/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.9.18)
# Requirement already satisfied: ratelimiter~=1.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.9.2)
# Requirement already satisfied: semver>=3.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.0.2)
# Requirement already satisfied: pyarrow>=12 in /opt/conda/envs/r/lib/python3.12/site-packages (from pylance==0.9.18->lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (15.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/r/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /opt/conda/envs/r/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.8.2)
# Requirement already satisfied: nodeenv>=1.6.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from pyright<2.0.0,>=1.1.350->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.8.0)
# Requirement already satisfied: iniconfig in /opt/conda/envs/r/lib/python3.12/site-packages (from pytest<9.0.0,>=8.0.0->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in /opt/conda/envs/r/lib/python3.12/site-packages (from pytest<9.0.0,>=8.0.0->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/r/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai[tools]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.17.2)
# Requirement already satisfied: contextlib2>=0.5.5 in /opt/conda/envs/r/lib/python3.12/site-packages (from schema<0.8.0,>=0.7.5->embedchain<0.2.0,>=0.1.98->crewai[tools]) (21.6.0)
# Requirement already satisfied: trio~=0.17 in /opt/conda/envs/r/lib/python3.12/site-packages (from selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/conda/envs/r/lib/python3.12/site-packages (from selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.11.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/envs/r/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=2.0.27->embedchain<0.2.0,>=0.1.98->crewai[tools]) (3.0.3)
# Requirement already satisfied: pyproject_hooks in /opt/conda/envs/r/lib/python3.12/site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.0.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /opt/conda/envs/r/lib/python3.12/site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.36.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from gitpython<4.0.0,>=3.1.38->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (4.0.11)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /home/jupyter/.local/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.59.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jupyter/.local/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jupyter/.local/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.6.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.12.7)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (1.5.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /opt/conda/envs/r/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.2.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.1.2)
# Requirement already satisfied: setuptools in /opt/conda/envs/r/lib/python3.12/site-packages (from nodeenv>=1.6.0->pyright<2.0.0,>=1.1.350->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (69.0.3)
# Requirement already satisfied: coloredlogs in /opt/conda/envs/r/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/conda/envs/r/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (24.3.7)
# Requirement already satisfied: sympy in /opt/conda/envs/r/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.12)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.44b0 in /opt/conda/envs/r/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.44b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.44b0 in /opt/conda/envs/r/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.44b0)
# Requirement already satisfied: opentelemetry-util-http==0.44b0 in /opt/conda/envs/r/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.44b0)
# Requirement already satisfied: asgiref~=3.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.8.1)
# Requirement already satisfied: pyjwt>=2.4.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.8.0)
# Requirement already satisfied: pynacl>=1.4.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.5.0)
# Requirement already satisfied: decorator>=3.4.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /opt/conda/envs/r/lib/python3.12/site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.11.0)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /opt/conda/envs/r/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.22.0)
# Requirement already satisfied: sortedcontainers in /opt/conda/envs/r/lib/python3.12/site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.4.0)
# Requirement already satisfied: outcome in /opt/conda/envs/r/lib/python3.12/site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /opt/conda/envs/r/lib/python3.12/site-packages (from trio-websocket~=0.9->selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.2.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.10->crewai[tools]) (1.0.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/conda/envs/r/lib/python3.12/site-packages (from urllib3[socks]<3,>=1.26->selenium<5.0.0,>=4.18.1->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.7.1)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/envs/r/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/envs/r/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (12.0)
# Requirement already satisfied: mutagen in /opt/conda/envs/r/lib/python3.12/site-packages (from yt_dlp<2024.0.0,>=2023.11.14->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.47.0)
# Requirement already satisfied: pycryptodomex in /opt/conda/envs/r/lib/python3.12/site-packages (from yt_dlp<2024.0.0,>=2023.11.14->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.20.0)
# Requirement already satisfied: brotli in /opt/conda/envs/r/lib/python3.12/site-packages (from yt_dlp<2024.0.0,>=2023.11.14->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/envs/r/lib/python3.12/site-packages (from Mako->alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (2.1.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.38->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (5.0.1)
# Requirement already satisfied: filelock in /opt/conda/envs/r/lib/python3.12/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2023.10.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/jupyter/.local/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.98->crewai[tools]) (0.5.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from pyjwt[crypto]>=2.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (42.0.5)
# Requirement already satisfied: cffi>=1.4.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from pynacl>=1.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/r/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/envs/r/lib/python3.12/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub<2.0.0,>=1.59.1->embedchain[github,youtube]<0.2.0,>=0.1.85->crewai-tools<0.2.0,>=0.1.7->crewai[tools]) (2.21)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading crewai_tools-0.1.7-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 870.5 kB/s eta 0:00:000:00:01
# Downloading pydantic-2.7.0-py3-none-any.whl (407 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.9/407.9 kB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_core-2.18.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.2 MB/s eta 0:00:00a 0:00:01
# Downloading crewai-0.28.8-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 10.9 MB/s eta 0:00:00
# Installing collected packages: appdirs, pydantic-core, pydantic, crewai, crewai-tools
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.1
#     Uninstalling pydantic_core-2.14.1:
#       Successfully uninstalled pydantic_core-2.14.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.0
#     Uninstalling pydantic-2.5.0:
#       Successfully uninstalled pydantic-2.5.0
#   Attempting uninstall: crewai
#     Found existing installation: crewai 0.22.5
#     Uninstalling crewai-0.22.5:
#       Successfully uninstalled crewai-0.22.5
#   Attempting uninstall: crewai-tools
#     Found existing installation: crewai-tools 0.0.15
#     Uninstalling crewai-tools-0.0.15:
#       Successfully uninstalled crewai-tools-0.0.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dspy-ai 2.4.5 requires pydantic==2.5.0, but you have pydantic 2.7.0 which is incompatible.
# Successfully installed appdirs-1.4.4 crewai-0.28.8 crewai-tools-0.1.7 pydantic-2.7.0 pydantic-core-2.18.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import re

PROJECT_ID = !(gcloud config get-value core/project)
PROJECT_ID = PROJECT_ID[0]

SVC_ACC = !(gcloud config get-value core/account)
SVC_ACC = SVC_ACC[0]

PROJECT_NUMBER=str(re.search(r'\d+', SVC_ACC).group())

LOCATION="asia-southeast1"

FOLDER_NAME="."

# %%
from crewai import Agent, Task, Crew, Process
from crewai_tools import tool
from crewai_tools.tools import FileReadTool
import os, requests, re, mdpdf, subprocess

# %%
# llm = ChatOpenAI(
#     openai_api_base="https://api.groq.com/openai/v1", # https://api.openai.com/v1 or https://api.groq.com/openai/v1 
#     openai_api_key=os.getenv("GROQ_API_KEY"), # os.getenv("OPENAI_API_KEY") or os.getenv("GROQ_API_KEY")
#     model_name="mixtral-8x7b-32768" #  gpt-4-turbo-preview or mixtral-8x7b-32768 
# )

# file_read_tool = FileReadTool(
# 	file_path='template.md',
# 	description='A tool to read the Story Template file and understand the expected output format.'
# )

# @tool
# def generateimage(chapter_content_and_character_details: str) -> str:
#     """
#     Generates an image for a given chapter number, chapter content, detailed location details and character details.
#     Using the OpenAI image generation API,
#     saves it in the current folder, and returns the image path.
#     """
#     client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

#     response = client.images.generate(
#         model="dall-e-3",
#         prompt=f"Image is about: {chapter_content_and_character_details}. Style: Illustration. Create an illustration incorporating a vivid palette with an emphasis on shades of azure and emerald, augmented by splashes of gold for contrast and visual interest. The style should evoke the intricate detail and whimsy of early 20th-century storybook illustrations, blending realism with fantastical elements to create a sense of wonder and enchantment. The composition should be rich in texture, with a soft, luminous lighting that enhances the magical atmosphere. Attention to the interplay of light and shadow will add depth and dimensionality, inviting the viewer to delve into the scene. DON'T include ANY text in this image. DON'T include colour palettes in this image.",
#         size="1024x1024",
#         quality="standard",
#         n=1,
#     )
#     image_url = response.data[0].url
#     words = chapter_content_and_character_details.split()[:5] 
#     safe_words = [re.sub(r'[^a-zA-Z0-9_]', '', word) for word in words]  
#     filename = "_".join(safe_words).lower() + ".png"
#     filepath = os.path.join(os.getcwd(), filename)

#     # Download the image from the URL
#     image_response = requests.get(image_url)
#     if image_response.status_code == 200:
#         with open(filepath, 'wb') as file:
#             file.write(image_response.content)
#     else:
#         print("Failed to download the image.")
#         return ""

#     return filepath

# @tool
# def convermarkdowntopdf(markdownfile_name: str) -> str:
#     """
#     Converts a Markdown file to a PDF document using the mdpdf command line application.

#     Args:
#         markdownfile_name (str): Path to the input Markdown file.

#     Returns:
#         str: Path to the generated PDF file.
#     """
#     output_file = os.path.splitext(markdownfile_name)[0] + '.pdf'
    
#     # Command to convert markdown to PDF using mdpdf
#     cmd = ['mdpdf', '--output', output_file, markdownfile_name]
    
#     # Execute the command
#     subprocess.run(cmd, check=True)
    
#     return output_file

# story_outliner = Agent(
#   role='Story Outliner',
#   goal='Develop an outline for a children\'s storybook about Animals, including chapter titles and characters for 5 chapters.',
#   backstory="An imaginative creator who lays the foundation of captivating stories for children.",
#   verbose=True,
#   llm=llm,
#   allow_delegation=False
# )

# story_writer = Agent(
#   role='Story Writer',
#   goal='Write the full content of the story for all 5 chapters, each chapter 100 words, weaving together the narratives and characters outlined.',
#   backstory="A talented storyteller who brings to life the world and characters outlined, crafting engaging and imaginative tales for children.",
#   verbose=True,
#   llm=llm,
#   allow_delegation=False
# )

# image_generator = Agent(
#   role='Image Generator',
#   goal='Generate one image per chapter content provided by the story outliner. Start with Chapter number, chapter content, character details, detailed location information and detailed items in the location where the activity happens. Generate totally 5 images one by one. Final output should contain all the 5 images in json format.',
#   backstory="A creative AI specialized in visual storytelling, bringing each chapter to life through imaginative imagery.",
#   verbose=True,
#   llm=llm,
#   tools=[generateimage],
#   allow_delegation=False
# )

# content_formatter = Agent(
#     role='Content Formatter',
#     goal='Format the written story content in markdown, including images at the beginning of each chapter.',
#     backstory='A meticulous formatter who enhances the readability and presentation of the storybook.',
#     verbose=True,
#     llm=llm,
#     tools=[file_read_tool],
#     allow_delegation=False
# )

# markdown_to_pdf_creator = Agent(
#     role='PDF Converter',
#     goal='Convert the Markdown file to a PDF document. story.md is the markdown file name.',
#     backstory='An efficient converter that transforms Markdown files into professionally formatted PDF documents.',
#     verbose=True,
#     llm=llm,
#     tools=[convermarkdowntopdf],
#     allow_delegation=False
# )


# # Create tasks for the agents
# task_outline = Task(
#     description='Create an outline for the children\'s storybook about Animals, detailing chapter titles and character descriptions for 5 chapters.',
#     agent=story_outliner,
#     expected_output='A structured outline document containing 5 chapter titles, with detailed character descriptions and the main plot points for each chapter.'
# )

# task_write = Task(
#     description='Using the outline provided, write the full story content for all chapters, ensuring a cohesive and engaging narrative for children. Each Chapter 100 words. Include Title of the story at the top.',
#     agent=story_writer,
#     expected_output='A complete manuscript of the children\'s storybook about Animals with 5 chapters. Each chapter should contain approximately 100 words, following the provided outline and integrating the characters and plot points into a cohesive narrative.'
# )

# task_image_generate = Task(
#     description='Generate 5 images that captures the essence of the children\'s storybook about Animals, aligning with the themes, characters, and narrative outlined for the chapters. Do it one by one.',
#     agent=image_generator,
#     expected_output='A digital image file that visually represents the overarching theme of the children\'s storybook, incorporating elements from the characters and plot as described in the outline. The image should be suitable for inclusion in the storybook as an illustration.',
# )

# task_format_content = Task(
#     description='Format the story content in markdown, including an image at the beginning of each chapter.',
#     agent=content_formatter,
#     expected_output='The entire storybook content formatted in markdown, with each chapter title followed by the corresponding image and the chapter content.',
#     context=[task_write, task_image_generate],
#     output_file="story.md"
# )

# task_markdown_to_pdf = Task(
#     description='Convert a Markdown file to a PDF document, ensuring the preservation of formatting, structure, and embedded images using the mdpdf library.',
#     agent=markdown_to_pdf_creator,
#     expected_output='A PDF file generated from the Markdown input, accurately reflecting the content with proper formatting. The PDF should be ready for sharing or printing.'
# )

# crew = Crew(
#   agents=[story_outliner, story_writer, image_generator, content_formatter, markdown_to_pdf_creator],
#   tasks=[task_outline, task_write, task_image_generate, task_format_content, task_markdown_to_pdf],
#   verbose=True,
#   process=Process.sequential
# )

# result = crew.kickoff()

# print(result)

# %%
# %pip install --upgrade --quiet  langchain-core langchain-google-vertexai
# %pip install mdpdf
# Out:
# Requirement already satisfied: mdpdf in /opt/conda/envs/r/lib/python3.12/site-packages (0.0.18)
# Requirement already satisfied: pymupdf>=1.21 in /opt/conda/envs/r/lib/python3.12/site-packages (from mdpdf) (1.24.0)
# Requirement already satisfied: commonmark>=0.9 in /opt/conda/envs/r/lib/python3.12/site-packages (from mdpdf) (0.9.1)
# Requirement already satisfied: click>=7.1 in /opt/conda/envs/r/lib/python3.12/site-packages (from mdpdf) (8.1.7)
# Requirement already satisfied: PyMuPDFb==1.24.0 in /opt/conda/envs/r/lib/python3.12/site-packages (from pymupdf>=1.21->mdpdf) (1.24.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# ! mdpdf -o output.pdf story.md

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, Part



def generate_pro(input_prompt):
    model = GenerativeModel("gemini-1.0-pro-002") #gemini-1.5-pro-preview-0409
    full_prompt = '''summarize the prompt below and do note prompt below will be send to imagen mode so please clean up any sensitve words and replace them into unblocked words like replace girl or lady can be replaced by female human and so on : ''' + input_prompt
    responses = model.generate_content(
    input_prompt,
    generation_config={
        "max_output_tokens": 8190,
        "temperature": 0.2,
        "top_p": 1
    },stream=False,)
    
    # print (responses.text)
    
    return(responses.text)


# input_prompt = '''
# Action 'generateimage(chapter_content_and_character_details={'chapter_content': 'Panic ensued in the animal kingdom as Professor Hoot, the wise old owl, was called upon to investigate. The mystery deepened as they searched for clues to unravel the enigma of Zeke's missing stripes.', 'character_details': 'Professor Hoot is a wise old owl'})' don't exist, these are the only available Actions: generateimage: generateimage(chapter_content_and_character_details: 'string') -      Generates an image using Imagen for a given chapter content and character details.     

# '''

# generate_pro(input_prompt)

# %%
from crewai import Agent, Task, Crew, Process
from crewai_tools import tool
# from langchain_vertexai import ChatGemini
from crewai_tools.tools import FileReadTool
import os, requests, re, mdpdf, subprocess
from vertexai.preview.vision_models import ImageGenerationModel
from langchain_google_vertexai import ChatVertexAI
import uuid, os

# Initialize Gemini LLM
llm = ChatVertexAI(
    model_name="gemini-1.0-pro-002", # Replace with your desired Gemini model
    project_id=os.getenv(PROJECT_ID), # Your Vertex AI project ID
    location="us-central1", # Your Vertex AI location
)

# Initialize Imagen model

@tool
def generateimage(chapter_content_and_character_details: str) -> str:
    """
    Generates an image using Imagen for a given chapter content and character details.
    """
    image_generation_model = ImageGenerationModel.from_pretrained("imagegeneration@006")

    chapter_content_and_character_details_refined = generate_pro(chapter_content_and_character_details)
    
    prompt = f"Image is about: {chapter_content_and_character_details_refined}. Style: Illustration. Create an illustration incorporating a vivid palette with an emphasis on shades of azure and emerald, augmented by splashes of gold for contrast and visual interest. The style should evoke the intricate detail and whimsy of early 20th-century storybook illustrations, blending realism with fantastical elements to create a sense of wonder and enchantment. The composition should be rich in texture, with a soft, luminous lighting that enhances the magical atmosphere. Attention to the interplay of light and shadow will add depth and dimensionality, inviting the viewer to delve into the scene. DON'T include ANY text in this image. DON'T include colour palettes in this image."

    response = image_generation_model.generate_images(
        prompt=prompt,
        aspect_ratio="1:1",
        number_of_images=1,
        safety_filter_level="block_some",
        person_generation="allow_adult",
    )
    
    # image_url = response.images[0].url
    image_url_name = str(uuid.uuid4())
    
    filepath = os.path.join(os.getcwd(), "images1/")

    LOCAL_PATH_TO_IMAGE = filepath+image_url_name+".jpg"
    response.images[0].save(location=image_url)
    print(LOCAL_PATH_TO_IMAGE)

    return(LOCAL_PATH_TO_IMAGE)

# %%
# generateimage("human female walking on road")
# image_url_name = str(uuid.uuid4())
# filepath=os.path.join(os.getcwd(), "images1/")
# image_url = filepath+image_url_name+".png"
# print(image_url)

# image_response = requests.get(image_url)
# if image_response.status_code == 200:
#     with open(filepath, 'wb') as file:
#         file.write(image_response.content)
# else:
#     print("Failed to download the image.")
    # return ""
# Out:
# /home/jupyter/GenAI5/ai_agents/images1/a8a1b66b-9716-4933-afa6-47561f19feeb.jpg
# /home/jupyter/GenAI5/ai_agents/images1/b88bf870-7850-4e2e-bfd5-73c393689ea5.png

# %%
# Instantiate tools
file_read_tool = FileReadTool(
	file_path='template.md',
	description='A tool to read the Story Template file and understand the expected output format.'
)

search_tool = DuckDuckGoSearchRun()


@tool
def convermarkdowntopdf(markdownfile_name: str) -> str:
    """
    Converts a Markdown file to a PDF document using the mdpdf command line application.

    Args:
        markdownfile_name (str): Path to the input Markdown file.

    Returns:
        str: Path to the generated PDF file.
    """
    output_file = os.path.splitext(markdownfile_name)[0] + '.pdf'
    
    # Command to convert markdown to PDF using mdpdf
    cmd = ['mdpdf', '--output', output_file, markdownfile_name]
    
    # Execute the command
    subprocess.run(cmd, check=True)
    
    return output_file

story_outliner = Agent(
  role='Story Outliner',
  goal='Develop an outline for a children\'s storybook about Animals, including chapter titles and characters for 5 chapters.',
  backstory="An imaginative creator who lays the foundation of captivating stories for children.",
  verbose=True,
  llm=llm,
  allow_delegation=False
)

story_writer = Agent(
  role='Story Writer',
  goal='Write the full content of the story for all 5 chapters, each chapter 100 words, weaving together the narratives and characters outlined.',
  backstory="A talented storyteller who brings to life the world and characters outlined, crafting engaging and imaginative tales for children.",
  verbose=True,
  llm=llm,
  allow_delegation=False
)

image_generator = Agent(
  role='Image Generator',
  goal='Generate one image per chapter content provided by the story outliner. Start with Chapter number, chapter content, character details, detailed location information and detailed items in the location where the activity happens. Generate totally 5 images one by one. Final output should contain all the 5 images in json format.',
  backstory="A creative AI specialized in visual storytelling, bringing each chapter to life through imaginative imagery.",
  verbose=True,
  llm=llm,
  tools=[generateimage],
  allow_delegation=False
)

content_formatter = Agent(
    role='Content Formatter',
    goal='Format the written story content in markdown, including images at the beginning of each chapter.',
    backstory='A meticulous formatter who enhances the readability and presentation of the storybook.',
    verbose=True,
    llm=llm,
    tools=[file_read_tool],
    allow_delegation=False
)

markdown_to_pdf_creator = Agent(
    role='PDF Converter',
    goal='Convert the Markdown file to a PDF document. story.md is the markdown file name.',
    backstory='An efficient converter that transforms Markdown files into professionally formatted PDF documents.',
    verbose=True,
    llm=llm,
    tools=[convermarkdowntopdf],
    allow_delegation=False
)


# Create tasks for the agents
task_outline = Task(
    description='Create an outline for the children\'s storybook about Animals, detailing chapter titles and character descriptions for 5 chapters.',
    agent=story_outliner,
    expected_output='A structured outline document containing 5 chapter titles, with detailed character descriptions and the main plot points for each chapter.'
)

task_write = Task(
    description='Using the outline provided, write the full story content for all chapters, ensuring a cohesive and engaging narrative for children. Each Chapter 100 words. Include Title of the story at the top.',
    agent=story_writer,
    expected_output='A complete manuscript of the children\'s storybook about Animals with 5 chapters. Each chapter should contain approximately 100 words, following the provided outline and integrating the characters and plot points into a cohesive narrative.'
)

task_image_generate = Task(
    description='Generate 5 images that captures the essence of the children\'s storybook about Animals, aligning with the themes, characters, and narrative outlined for the chapters. Do it one by one.',
    agent=image_generator,
    expected_output='A digital image file that visually represents the overarching theme of the children\'s storybook, incorporating elements from the characters and plot as described in the outline. The image should be suitable for inclusion in the storybook as an illustration.',
)

task_format_content = Task(
    description='Format the story content in markdown, including an image at the beginning of each chapter.',
    agent=content_formatter,
    expected_output='The entire storybook content formatted in markdown, with each chapter title followed by the corresponding image and the chapter content.',
    context=[task_write, task_image_generate],
    output_file="story.md"
)

task_markdown_to_pdf = Task(
    description='Convert a Markdown file to a PDF document, ensuring the preservation of formatting, structure, and embedded images using the mdpdf library.',
    agent=markdown_to_pdf_creator,
    expected_output='A PDF file generated from the Markdown input, accurately reflecting the content with proper formatting. The PDF should be ready for sharing or printing.'
)

crew = Crew(
  agents=[story_outliner, story_writer, image_generator, content_formatter, markdown_to_pdf_creator],
  tasks=[task_outline, task_write, task_image_generate, task_format_content, task_markdown_to_pdf],
  verbose=True,
  process=Process.sequential
)

result = crew.kickoff()

print(result)
